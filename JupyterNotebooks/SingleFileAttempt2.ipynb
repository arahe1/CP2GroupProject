# %%
import uproot
import awkward as ak
import numpy as np
from IPython.display import display

# %%
file = uproot.open("/lstr/sahara/dune/arahe/CP2Course/CP2GroupProject/TylerStuff/NuTau_art_MuTest_SingleFile/prodgenie_nuCC_dune10kt_1x2x6_1000evts_gen_g4_detsim_reco_251.root")

# %%
file.keys()
# Out:
# ['RootFileDB;1',
#  'MetaData;1',
#  'FileIndex;1',
#  'Parentage;1',
#  'Events;1',
#  'EventMetaData;1',
#  'SubRuns;1',
#  'SubRunMetaData;1',
#  'Runs;1',
#  'RunMetaData;1',
#  'ResultsTree;1',
#  'ResultsMetaData;1']

# %%
tree = file["Events;1"]

# %%
#tree.keys()

# %%
branch = tree["dune::EnergyRecoOutputrecob::Trackvoidart::Assns_energyrecnue__Reco."]

# %%
branch.keys()
# Out:
# ['dune::EnergyRecoOutputrecob::Trackvoidart::Assns_energyrecnue__Reco.present',
#  'dune::EnergyRecoOutputrecob::Trackvoidart::Assns_energyrecnue__Reco.rangeSetID',
#  'dune::EnergyRecoOutputrecob::Trackvoidart::Assns_energyrecnue__Reco.obj']

# %%
branch.show()
# Out:
# name                 | typename                 | interpretation
# ---------------------+--------------------------+-------------------------------
# dune::EnergyRecoOutp | art::Wrapper<art::Assns< | AsGroup(<TBranchElement 'dune:
# dune::EnergyRecoO... | bool                     | AsDtype('bool')
# dune::EnergyRecoO... | uint32_t                 | AsDtype('>u4')
# dune::EnergyRecoO... | unknown                  | <UnknownInterpretation 'non...

# %%
stick = branch["dune::EnergyRecoOutputrecob::Trackvoidart::Assns_energyrecnue__Reco.obj"]

# %%
stick.keys()
# Out:
# []

# %%
stick.interpretation
# Out:
# <UnknownInterpretation 'none of the rules matched'>

# %%
print(f"Branch name: {stick.name}, Branch type: {stick.typename}")
# Out:
# Branch name: dune::EnergyRecoOutputrecob::Trackvoidart::Assns_energyrecnue__Reco.obj, Branch type: unknown

# %%
#twig = branch.array(["simb::MCParticles_largeant__G4.obj"])

# %%
EnergyReco = branch.arrays(['dune::EnergyRecoOutputrecob::Trackvoidart::Assns_energyrecnue__Reco.present',
 'dune::EnergyRecoOutputrecob::Trackvoidart::Assns_energyrecnue__Reco.rangeSetID',
 'dune::EnergyRecoOutputrecob::Trackvoidart::Assns_energyrecnue__Reco.obj'])
# Out:
# ---------------------------------------------------------------------------
# UnknownInterpretation                     Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 EnergyReco = branch.arrays(['dune::EnergyRecoOutputrecob::Trackvoidart::Assns_energyrecnue__Reco.present',
#       2  'dune::EnergyRecoOutputrecob::Trackvoidart::Assns_energyrecnue__Reco.rangeSetID',
#       3  'dune::EnergyRecoOutputrecob::Trackvoidart::Assns_energyrecnue__Reco.obj'])
#
# File ~/.conda/envs/columnar_env/lib/python3.12/site-packages/uproot/behaviors/TBranch.py:803, in HasBranches.arrays(self, expressions, cut, filter_name, filter_typename, filter_branch, aliases, language, entry_start, entry_stop, decompression_executor, interpretation_executor, array_cache, library, ak_add_doc, how)
#     800         return None
#     802 aliases = _regularize_aliases(self, aliases)
# --> 803 arrays, expression_context, branchid_interpretation = _regularize_expressions(
#     804     self,
#     805     expressions,
#     806     cut,
#     807     filter_name,
#     808     filter_typename,
#     809     filter_branch,
#     810     keys,
#     811     aliases,
#     812     language,
#     813     get_from_cache,
#     814 )
#     816 ranges_or_baskets = []
#     817 checked = set()
#
# File ~/.conda/envs/columnar_env/lib/python3.12/site-packages/uproot/behaviors/TBranch.py:2914, in _regularize_expressions(hasbranches, expressions, cut, filter_name, filter_typename, filter_branch, keys, aliases, language, get_from_cache)
#    2912 for expression, interp in items:
#    2913     if interp is None:
# -> 2914         _regularize_expression(
#    2915             hasbranches,
#    2916             expression,
#    2917             keys,
#    2918             aliases,
#    2919             language,
#    2920             get_from_cache,
#    2921             arrays,
#    2922             expression_context,
#    2923             branchid_interpretation,
#    2924             (),
#    2925             False,
#    2926             None,
#    2927         )
#    2928     else:
#    2929         branch = hasbranches[expression]
#
# File ~/.conda/envs/columnar_env/lib/python3.12/site-packages/uproot/behaviors/TBranch.py:2763, in _regularize_expression(hasbranches, expression, keys, aliases, language, get_from_cache, arrays, expression_context, branchid_interpretation, symbol_path, is_cut, rename)
#    2761 branch = hasbranches.get(expression)
#    2762 if branch is not None:
# -> 2763     _regularize_branchname(
#    2764         hasbranches,
#    2765         expression,
#    2766         branch,
#    2767         branch.interpretation,
#    2768         get_from_cache,
#    2769         arrays,
#    2770         expression_context,
#    2771         branchid_interpretation,
#    2772         is_primary,
#    2773         is_cut,
#    2774     )
#    2776 else:
#    2777     # the value of `expression` is either what we want to compute or a lookup value for it
#    2778     to_compute = aliases.get(expression, expression)
#
# File ~/.conda/envs/columnar_env/lib/python3.12/site-packages/uproot/behaviors/TBranch.py:2694, in _regularize_branchname(hasbranches, branchname, branch, interpretation, get_from_cache, arrays, expression_context, branchid_interpretation, is_primary, is_cut)
#    2682 def _regularize_branchname(
#    2683     hasbranches,
#    2684     branchname,
#    (...)
#    2692     is_cut,
#    2693 ):
# -> 2694     got = get_from_cache(branchname, interpretation)
#    2695     if got is not None:
#    2696         arrays[branch.cache_key] = got
#
# File ~/.conda/envs/columnar_env/lib/python3.12/site-packages/uproot/behaviors/TBranch.py:797, in HasBranches.arrays.<locals>.get_from_cache(branchname, interpretation)
#     795 def get_from_cache(branchname, interpretation):
#     796     if array_cache is not None:
# --> 797         cache_key = f"{self.cache_key}:{branchname}:{interpretation.cache_key}:{entry_start}-{entry_stop}:{library.name}"
#     798         return array_cache.get(cache_key)
#     799     else:
#
# File ~/.conda/envs/columnar_env/lib/python3.12/site-packages/uproot/interpretation/identify.py:1165, in UnknownInterpretation.cache_key(self)
#    1163 @property
#    1164 def cache_key(self):
# -> 1165     raise self
#
# File ~/.conda/envs/columnar_env/lib/python3.12/site-packages/uproot/behaviors/TBranch.py:1945, in TBranch.interpretation(self)
#    1943 if self._interpretation is None:
#    1944     try:
# -> 1945         self._interpretation = uproot.interpretation.identify.interpretation_of(
#    1946             self, {}
#    1947         )
#    1948     except uproot.interpretation.identify.UnknownInterpretation as err:
#    1949         self._interpretation = err
#
# File ~/.conda/envs/columnar_env/lib/python3.12/site-packages/uproot/interpretation/identify.py:507, in interpretation_of(branch, context, simplify)
#     504         else:
#     505             return out
# --> 507 raise UnknownInterpretation(
#     508     "none of the rules matched",
#     509     branch.file.file_path,
#     510     branch.object_path,
#     511 )
#
# UnknownInterpretation: none of the rules matched
# in file /lstr/sahara/dune/arahe/CP2Course/CP2GroupProject/TylerStuff/NuTau_art_MuTest_SingleFile/prodgenie_nuCC_dune10kt_1x2x6_1000evts_gen_g4_detsim_reco_251.root
# in object /Events;1:dune::EnergyRecoOutputrecob::Trackvoidart::Assns_energyrecnue__Reco./dune::EnergyRecoOutputrecob::Trackvoidart::Assns_energyrecnue__Reco.obj

# %%
Energy = ak.zip({
    "present" : EnergyReco["dune::EnergyRecoOutput_energyrecnumu__Reco.present"],
    "rangeID" : EnergyReco["dune::EnergyRecoOutput_energyrecnumu__Reco.rangeSetID"],
    "obj" : EnergyReco["dune::EnergyRecoOutput_energyrecnumu__Reco.obj"]
})

# %%
print(EnergyReco["dune::EnergyRecoOutput_energyrecnumu__Reco.obj"])
# Out:
# [{recoMethodUsed: 0, fRecoVertex: {...}, fNuLorentzVector: {...}, ...}, ...]

# %%
Energy.obj.fRecoVertex
# Out:
# <Array [{fCoordinates: {...}}, ..., {...}] type='1000 * struct[{fCoordinate...'>
